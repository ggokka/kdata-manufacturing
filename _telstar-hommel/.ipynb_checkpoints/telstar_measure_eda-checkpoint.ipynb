# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('telstar_measure_data.xlsx', sheet_name='PartTrackingReport')
df
# Out:
#          공장   라인                    투입시간                생산일자(완성)  \
# 0       NaN  NaN                     NaN                     NaN
# 1       NaN  NaN                     NaN                     NaN
# 2       NaN  NaN                     NaN                     NaN
# 3     신U 조립    U   2019-06-01 오전 8:40:08   2019-06-01 오전 9:43:11
# 4     신U 조립    U   2019-06-01 오전 8:40:38   2019-06-01 오전 9:44:13
# 5     신U 조립    U   2019-06-01 오전 8:40:59   2019-06-01 오전 9:45:12
# 6     신U 조립    U   2019-06-01 오전 8:41:29   2019-06-01 오전 9:46:20
# 7     신U 조립    U   2019-06-01 오전 8:41:50   2019-06-01 오전 9:47:31
# 8     신U 조립    U   2019-06-01 오전 8:42:20   2019-06-01 오전 9:48:15
# 9     신U 조립    U   2019-06-01 오전 8:43:11   2019-06-01 오전 9:49:05
# 10    신U 조립    U   2019-06-01 오전 8:43:41   2019-06-01 오전 9:50:19
# 11    신U 조립    U   2019-06-01 오전 8:44:02  2019-06-01 오전 10:18:30
# 12    신U 조립    U   2019-06-01 오전 8:44:32   2019-06-01 오전 9:53:43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8823 entries, 0 to 8822
# Columns: 143 entries, 공장 to Unnamed: 142
# dtypes: object(143)
# memory usage: 9.6+ MB

# %%
ds = df[3:]

# %%
ds.boxplot(column=['POP_010_020'], by='POP_010_030')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-c9c986c462ca> in <module>
# ----> 1 ds.boxplot(column=['POP_010_020'], by='POP_010_030')
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
bp = df.boxplot(column=['공장'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9dab0aec4e69> in <module>
# ----> 1 bp = df.boxplot(column=['공장'])
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2239             columns = data.columns
#    2240         else:
# -> 2241             data = data[columns]
#    2242
# ...

# %%
df.columns
# Out:
# Index(['공장', '라인', '투입시간', '생산일자(완성)', '파트시리얼', 'POP_010_020', 'Unnamed: 6',
#        'POP_010_030', 'Unnamed: 8', 'POP_010_040',
#        ...
#        'POP_080_030', 'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136',
#        'Unnamed: 137', 'Unnamed: 138', 'Unnamed: 139', 'Unnamed: 140',
#        'Unnamed: 141', 'Unnamed: 142'],
#       dtype='object', length=143)

# %%
df['공장']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3       신U 조립
# 4       신U 조립
# 5       신U 조립
# 6       신U 조립
# 7       신U 조립
# 8       신U 조립
# 9       신U 조립
# 10      신U 조립
# 11      신U 조립
# 12      신U 조립
# 13      신U 조립
# 14      신U 조립
# 15      신U 조립
# 16      신U 조립
# 17      신U 조립
# 18      신U 조립
# 19      신U 조립
# 20      신U 조립
# 21      신U 조립
# 22      신U 조립
# 23      신U 조립
# 24      신U 조립
# 25      신U 조립
# 26      신U 조립
# 27      신U 조립
# 28      신U 조립
# 29      신U 조립
#         ...
# 8793    신U 조립
# 8794    신U 조립
# 8795    신U 조립
# 8796    신U 조립
# 8797    신U 조립
# 8798    신U 조립
# 8799    신U 조립
# 8800    신U 조립
# 8801    신U 조립
# 8802    신U 조립
# 8803    신U 조립
# 8804    신U 조립
# 8805    신U 조립
# 8806    신U 조립
# 8807    신U 조립
# 8808    신U 조립
# 8809    신U 조립
# 8810    신U 조립
# 8811    신U 조립
# 8812    신U 조립
# 8813    신U 조립
# 8814    신U 조립
# 8815    신U 조립
# 8816    신U 조립
# 8817    신U 조립
# 8818    신U 조립
# 8819    신U 조립
# 8820    신U 조립
# 8821    신U 조립
# 8822    신U 조립
# ...

# %%
ds.columns = ['1','2','3','4','5','6','7','8','9']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-8fef3538dac9> in <module>
# ----> 1 ds.columns = ['1','2','3','4','5','6','7','8','9']
#
# d:\program files\python36\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# d:\program files\python36\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ...

# %%
col_idx_arr = [str(i) for i in range(len(ds.columns))]

# %%
ds.columns = col_idx_arr

# %%
ds
# Out:
#           0  1                       2                       3  \
# 3     신U 조립  U   2019-06-01 오전 8:40:08   2019-06-01 오전 9:43:11
# 4     신U 조립  U   2019-06-01 오전 8:40:38   2019-06-01 오전 9:44:13
# 5     신U 조립  U   2019-06-01 오전 8:40:59   2019-06-01 오전 9:45:12
# 6     신U 조립  U   2019-06-01 오전 8:41:29   2019-06-01 오전 9:46:20
# 7     신U 조립  U   2019-06-01 오전 8:41:50   2019-06-01 오전 9:47:31
# 8     신U 조립  U   2019-06-01 오전 8:42:20   2019-06-01 오전 9:48:15
# 9     신U 조립  U   2019-06-01 오전 8:43:11   2019-06-01 오전 9:49:05
# 10    신U 조립  U   2019-06-01 오전 8:43:41   2019-06-01 오전 9:50:19
# 11    신U 조립  U   2019-06-01 오전 8:44:02  2019-06-01 오전 10:18:30
# 12    신U 조립  U   2019-06-01 오전 8:44:32   2019-06-01 오전 9:53:43
# 13    신U 조립  U   2019-06-01 오전 8:45:02   2019-06-01 오전 9:54:20
# 14    신U 조립  U   2019-06-01 오전 8:45:23   2019-06-01 오전 9:55:47
# 15    신U 조립  U   2019-06-01 오전 8:45:53   2019-06-01 오전 9:56:48
# 16    신U 조립  U   2019-06-01 오전 8:46:24   2019-06-01 오전 9:57:56
# ...

# %%
ds.boxplot(column=['5'], by='0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-eda9de19bc5b> in <module>
# ----> 1 ds.boxplot(column=['5'], by='0')
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
ds1 = ds.dropna(axis=0)
ds1
# Out:
#           0  1                       2                       3  \
# 3     신U 조립  U   2019-06-01 오전 8:40:08   2019-06-01 오전 9:43:11
# 4     신U 조립  U   2019-06-01 오전 8:40:38   2019-06-01 오전 9:44:13
# 5     신U 조립  U   2019-06-01 오전 8:40:59   2019-06-01 오전 9:45:12
# 6     신U 조립  U   2019-06-01 오전 8:41:29   2019-06-01 오전 9:46:20
# 7     신U 조립  U   2019-06-01 오전 8:41:50   2019-06-01 오전 9:47:31
# 8     신U 조립  U   2019-06-01 오전 8:42:20   2019-06-01 오전 9:48:15
# 9     신U 조립  U   2019-06-01 오전 8:43:11   2019-06-01 오전 9:49:05
# 10    신U 조립  U   2019-06-01 오전 8:43:41   2019-06-01 오전 9:50:19
# 11    신U 조립  U   2019-06-01 오전 8:44:02  2019-06-01 오전 10:18:30
# 12    신U 조립  U   2019-06-01 오전 8:44:32   2019-06-01 오전 9:53:43
# 13    신U 조립  U   2019-06-01 오전 8:45:02   2019-06-01 오전 9:54:20
# 14    신U 조립  U   2019-06-01 오전 8:45:23   2019-06-01 오전 9:55:47
# 15    신U 조립  U   2019-06-01 오전 8:45:53   2019-06-01 오전 9:56:48
# 16    신U 조립  U   2019-06-01 오전 8:46:24   2019-06-01 오전 9:57:56
# ...

# %%
ds1.boxplot(column=['5'], by='6')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-78254982b493> in <module>
# ----> 1 ds1.boxplot(column=['5'], by='6')
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# d:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
ds1["1"].describe()
# Out:
# count     8684
# unique       1
# top          U
# freq      8684
# Name: 1, dtype: object

# %%
ds1["5"] = ds1["5"].astype(float)
ds1["6"] = ds1["6"].astype(float)
ds1.dtypes
# Out:
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0       object
# 1       object
# 2       object
# 3       object
# 4       object
# 5      float64
# 6      float64
# 7       object
# 8       object
# 9       object
# 10      object
# 11      object
# 12      object
# 13      object
# ...

# %%
ds1.boxplot(column=['5'], by='6')

# %%
ds1 = ds1.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-5a2b550d11bf> in <module>
# ----> 1 ds1 = ds1.astype(float)
#
# d:\program files\python36\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# d:\program files\python36\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
ds1["7"] = ds1["7"].astype(float)
ds1["8"] = ds1["8"].astype(float)
# Out:
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# d:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ds1.boxplot(column=['7'], by='8')

# %%
ds1.plot.scatter(x='5', y='6')

# %%
ds1.corr(method='pearson')
# Out:
#               5             6             7             8
# 5  1.000000e+00  1.198990e-01  2.355684e-01 -1.630753e-13
# 6  1.198990e-01  1.000000e+00  4.493365e-02 -4.537778e-08
# 7  2.355684e-01  4.493365e-02  1.000000e+00  1.683208e-13
# 8 -1.630753e-13 -4.537778e-08  1.683208e-13  1.000000e+00
