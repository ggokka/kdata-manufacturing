# %%
import pandas as pd

# %%
df = pd.read_excel('data1.xlsx')

# %%
df[3:5]
# Out:
#        H 라인                   투입시간               생산일자(완성)            파트시리얼  \
# 3  신U 조립  U  2019-06-01 오전 8:41:29  2019-06-01 오전 9:46:20  19051623360149A
# 4  신U 조립  U  2019-06-01 오전 8:41:50  2019-06-01 오전 9:47:31  19051623350148A
#
#    SRING_Assy_DATA  SEAL_PRESS_LOAD  SEAL_PRESS_DISTANCE  NR_DATA#1  \
# 3            0.798           32.227              141.399       10.8
# 4            0.611           39.551              141.399       10.8
#
#    NR_DATA#2  ...  IVM_Cover_체결_토크_1  IVM_Cover_체결_토크_2  IVM_Cover_체결_토크_3  \
# 3       10.8  ...               11.5               11.5               11.5
# 4       10.8  ...               11.5               11.5               11.5
#
#    IVM_Cover_체결_토크_4  IVM_Cover_체결_토크_5  IVM_Cover_체결_토크_6  Bottom_다윌핀_압입력_1  \
# 3               11.5               11.6               11.5           468.750
# 4               11.5               11.5               11.6           427.735
#
#    Bottom_다윌핀_압입력_2  캠스프라켓_체결_토크  완성_리크테스트값
# ...

# %%
df.loc[3:5]
# Out:
#        H 라인                   투입시간               생산일자(완성)            파트시리얼  \
# 3  신U 조립  U  2019-06-01 오전 8:41:29  2019-06-01 오전 9:46:20  19051623360149A
# 4  신U 조립  U  2019-06-01 오전 8:41:50  2019-06-01 오전 9:47:31  19051623350148A
# 5  신U 조립  U  2019-06-01 오전 8:42:20  2019-06-01 오전 9:48:15  19051623370150A
#
#    SRING_Assy_DATA  SEAL_PRESS_LOAD  SEAL_PRESS_DISTANCE  NR_DATA#1  \
# 3            0.798           32.227              141.399       10.8
# 4            0.611           39.551              141.399       10.8
# 5            0.523           35.157              141.399       10.7
#
#    NR_DATA#2  ...  IVM_Cover_체결_토크_1  IVM_Cover_체결_토크_2  IVM_Cover_체결_토크_3  \
# 3       10.8  ...               11.5               11.5               11.5
# 4       10.8  ...               11.5               11.5               11.5
# 5       10.9  ...               11.5               11.5               11.5
#
#    IVM_Cover_체결_토크_4  IVM_Cover_체결_토크_5  IVM_Cover_체결_토크_6  Bottom_다윌핀_압입력_1  \
# ...

# %%
df.loc[df["SRING_Assy_DATA"] > 0.99]
# Out:
#           H 라인                    투입시간                생산일자(완성)  \
# 1610  신U 조립  U   2019-06-05 오후 2:04:13   2019-06-05 오후 3:50:29
# 3147  신U 조립  U   2019-06-11 오전 9:16:45  2019-06-11 오전 10:37:21
# 3487  신U 조립  U   2019-06-11 오후 4:42:24  2019-06-12 오전 11:48:45
# 4682  신U 조립  U   2019-06-17 오전 9:23:04  2019-06-17 오전 10:54:20
# 5489  신U 조립  U   2019-06-18 오후 6:08:01   2019-06-19 오전 9:38:04
# 6936  신U 조립  U  2019-06-25 오전 10:40:26   2019-06-25 오후 1:37:16
#
#                 파트시리얼  SRING_Assy_DATA  SEAL_PRESS_LOAD  SEAL_PRESS_DISTANCE  \
# 1610  19052218320373A            1.007           29.297              141.399
# 3147  19052415580336A            1.001           38.086              141.399
# 3487  19052722390084A            1.062           35.157              141.399
# 4682  19052904140336A            1.012           27.833              141.399
# 5489  19060201300205A            2.513           46.875              141.399
# ...

# %%
x =[]
for i in list(range(len(df.columns))):
    name = df.columns[i]
    counts = df[df.columns[i]].unique().shape[0]
    dtype = df.dtypes[i]
    x.append((name.counts.dtype))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ba4c6d86fbb6> in <module>
#       4     counts = df[df.columns[i]].unique().shape[0]
#       5     dtype = df.dtypes[i]
# ----> 6     x.append((name.counts.dtype))
#       7
#       8
#
# AttributeError: 'str' object has no attribute 'counts'
