# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('telstar_line_d.xlsx', sheet_name='part')
df.head()
# Out:
#       공장 라인                   투입시간               생산일자(완성)            파트시리얼  \
# 0  신U 조립  U  2019-06-01 오전 8:40:08  2019-06-01 오전 9:43:11  19051623310145A
# 1  신U 조립  U  2019-06-01 오전 8:40:38  2019-06-01 오전 9:44:13  19051623320146A
# 2  신U 조립  U  2019-06-01 오전 8:40:59  2019-06-01 오전 9:45:12  19051623330147A
# 3  신U 조립  U  2019-06-01 오전 8:41:29  2019-06-01 오전 9:46:20  19051623360149A
# 4  신U 조립  U  2019-06-01 오전 8:41:50  2019-06-01 오전 9:47:31  19051623350148A
#
#    S/RING_Assy_DATA  SEAL_PRESS_LOAD  SEAL_PRESS_DISTANCE  N/R_DATA#1  \
# 0             0.585           36.622              141.399        10.9
# 1             0.633           41.016              141.399        10.9
# 2             0.650           39.551              141.399        10.8
# 3             0.798           32.227              141.399        10.8
# 4             0.611           39.551              141.399        10.8
#
#    N/R_DATA#2  ...  IVM_Cover_체결_토크_3  IVM_Cover_체결_토크_4  IVM_Cover_체결_토크_5  \
# 0        10.8  ...               11.5               11.5               11.5
# 1        10.8  ...               11.5               11.5               11.5
# 2        10.8  ...               11.5               11.5               11.5
# 3        10.8  ...               11.5               11.5               11.6
# 4        10.8  ...               11.5               11.5               11.5
#
#    IVM_Cover_체결_토크_6  Bottom_다윌핀_압입력_1  Bottom_다윌핀_압입거리_1  Bottom_다윌핀_압입력_2  \
# 0               11.5           408.692            182.997           432.129
# 1               11.5           474.610            182.997           382.325
# 2               11.5           470.215            182.997           350.098
# 3               11.5           468.750            182.997           388.184
# 4               11.6           427.735            182.997           360.352
#
#    Bottom_다윌핀_압입거리_2  캠스프라켓_체결_토크  완성_리크테스트값
# 0            182.498        107.2     -2.776
# 1            182.498        107.4     -1.471
# 2            182.498        107.1     -2.841
# 3            182.498        107.1    -13.169
# 4            182.498        107.1      0.913
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#        S/RING_Assy_DATA  SEAL_PRESS_LOAD  SEAL_PRESS_DISTANCE   N/R_DATA#1  \
# count       8716.000000      8715.000000          8715.000000  8701.000000
# mean           0.650065        34.358024           141.398498    10.824112
# std            0.130203         6.527553             0.038167     0.058527
# min            0.180000        21.973000           137.961000    10.700000
# 25%            0.555000        30.762000           141.399000    10.800000
# 50%            0.660000        33.692000           141.399000    10.800000
# 75%            0.746000        36.622000           141.399000    10.900000
# max            2.513000       131.836000           141.400000    11.000000
#
#         N/R_DATA#2   N/R_DATA#3  EX_FRT_리크테스트값  Top_다윌핀_압입력_1  Top_다월핀_압입거리_1  \
# count  8701.000000  8701.000000    8700.000000    8694.000000    8.694000e+03
# mean     10.828663    10.819630       0.459352     175.471880    1.392980e+02
# std       0.053446     0.054801      18.548569      25.780432    2.450092e-11
# min      10.700000    10.700000      -1.600000     127.442000    1.392980e+02
# 25%      10.800000    10.800000       0.037000     149.415000    1.392980e+02
# 50%      10.800000    10.800000       0.081000     178.711000    1.392980e+02
# 75%      10.900000    10.900000       0.142000     197.754000    1.392980e+02
# max      11.000000    11.000000     999.000000     244.629000    1.392980e+02
#
#        Top_다윌핀_압입력_2  ...  IVM_Cover_체결_토크_3  IVM_Cover_체결_토크_4  \
# count    8694.000000  ...        8692.000000        8693.000000
# mean      408.928952  ...          11.504567          11.515219
# std        48.427015  ...           0.020879           0.036114
# min       287.110000  ...          11.500000          11.200000
# 25%       373.536000  ...          11.500000          11.500000
# 50%       402.833000  ...          11.500000          11.500000
# 75%       437.989000  ...          11.500000          11.500000
# max       600.586000  ...          11.600000          11.600000
#
#        IVM_Cover_체결_토크_5  IVM_Cover_체결_토크_6  Bottom_다윌핀_압입력_1  \
# count        8692.000000        8693.000000       8692.000000
# mean           11.509238          11.503532        417.311584
# std             0.030355           0.036628         35.731945
# min            10.700000           8.800000        200.000000
# 25%            11.500000          11.500000        394.043000
# 50%            11.500000          11.500000        416.016000
# 75%            11.500000          11.500000        439.454000
# max            11.600000          11.600000        550.000000
#
#        Bottom_다윌핀_압입거리_1  Bottom_다윌핀_압입력_2  Bottom_다윌핀_압입거리_2  캠스프라켓_체결_토크  \
# count       8.692000e+03       8692.000000        8692.000000  8692.000000
# mean        1.829970e+02        358.068562         182.497970   107.294765
# std         2.134593e-11         24.620714           0.001112     0.227262
# min         1.829970e+02        215.333000         182.497000   106.400000
# 25%         1.829970e+02        342.774000         182.498000   107.100000
# 50%         1.829970e+02        357.422000         182.498000   107.300000
# 75%         1.829970e+02        373.536000         182.498000   107.400000
# max         1.829970e+02        459.961000         182.600000   108.200000
#
#          완성_리크테스트값
# count  8691.000000
# mean     -2.006442
# std       5.391602
# min     -14.993000
# 25%      -5.443500
# 50%      -1.934000
# 75%       1.243000
# max      16.998000
#
# [8 rows x 27 columns]

# %%
df_notnull = df.dropna();

# %%
df_notnull.describe()
# Out:
#        S/RING_Assy_DATA  SEAL_PRESS_LOAD  SEAL_PRESS_DISTANCE   N/R_DATA#1  \
# count       8687.000000      8687.000000           8687.00000  8687.000000
# mean           0.650025        34.290192            141.39900    10.824116
# std            0.130265         6.187274              0.00007     0.058531
# min            0.180000        21.973000            141.39800    10.700000
# 25%            0.555000        30.762000            141.39900    10.800000
# 50%            0.660000        33.692000            141.39900    10.800000
# 75%            0.746000        36.622000            141.39900    10.900000
# max            2.513000       111.329000            141.40000    11.000000
#
#         N/R_DATA#2   N/R_DATA#3  EX_FRT_리크테스트값  Top_다윌핀_압입력_1  Top_다월핀_압입거리_1  \
# count  8687.000000  8687.000000    8687.000000    8687.000000    8.687000e+03
# mean     10.828664    10.819592       0.111027     175.475677    1.392980e+02
# std       0.053437     0.054801       0.157615      25.783814    2.447250e-11
# min      10.700000    10.700000      -1.600000     127.442000    1.392980e+02
# 25%      10.800000    10.800000       0.037000     149.415000    1.392980e+02
# 50%      10.800000    10.800000       0.081000     178.711000    1.392980e+02
# 75%      10.900000    10.900000       0.142000     197.754000    1.392980e+02
# max      11.000000    11.000000       2.980000     244.629000    1.392980e+02
#
#        Top_다윌핀_압입력_2  ...  IVM_Cover_체결_토크_3  IVM_Cover_체결_토크_4  \
# count    8687.000000  ...        8687.000000        8687.000000
# mean      408.934708  ...          11.504570          11.515218
# std        48.439793  ...           0.020885           0.036114
# min       287.110000  ...          11.500000          11.200000
# 25%       373.536000  ...          11.500000          11.500000
# 50%       402.833000  ...          11.500000          11.500000
# 75%       437.989000  ...          11.500000          11.500000
# max       600.586000  ...          11.600000          11.600000
#
#        IVM_Cover_체결_토크_5  IVM_Cover_체결_토크_6  Bottom_다윌핀_압입력_1  \
# count        8687.000000        8687.000000       8687.000000
# mean           11.509232          11.503845        417.304236
# std             0.030348           0.022383         35.732837
# min            10.700000          10.700000        200.000000
# 25%            11.500000          11.500000        394.043000
# 50%            11.500000          11.500000        416.016000
# 75%            11.500000          11.500000        439.454000
# max            11.600000          11.600000        550.000000
#
#        Bottom_다윌핀_압입거리_1  Bottom_다윌핀_압입력_2  Bottom_다윌핀_압입거리_2  캠스프라켓_체결_토크  \
# count       8.687000e+03       8687.000000        8687.000000  8687.000000
# mean        1.829970e+02        358.064718         182.497970   107.294705
# std         2.134593e-11         24.623195           0.001113     0.227126
# min         1.829970e+02        215.333000         182.497000   106.400000
# 25%         1.829970e+02        342.774000         182.498000   107.150000
# 50%         1.829970e+02        357.422000         182.498000   107.300000
# 75%         1.829970e+02        373.536000         182.498000   107.400000
# max         1.829970e+02        459.961000         182.600000   108.200000
#
#          완성_리크테스트값
# count  8687.000000
# mean     -2.008805
# std       5.391157
# min     -14.993000
# 25%      -5.444500
# 50%      -1.935000
# 75%       1.242000
# max      16.998000
#
# [8 rows x 27 columns]

# %%
# 2-1. Multiple histograms on the same axis

var_color_dict = {'S/RING_Assy_DATA': 'blue', 
                      'SEAL_PRESS_LOAD': 'red', 
                      'SEAL_PRESS_DISTANCE': 'yellow', 
                      'N/R_DATA#1': 'green'}
# for loop
for var in var_color_dict:
    sns.distplot(df_notnull[var],
                    color = var_color_dict[var],
                    hist_kws = {'edgecolor': 'gray'},
                    label = var)

plt.legend(title = 'Variables')
plt.show()

#출처: https://rfriend.tistory.com/409 [R, Python 분석과 프로그래밍 (by R Friend)]

# %%
bins = np.linspace(-10, 20, 100)

plt.hist(df_notnull['S/RING_Assy_DATA'], bins, alpha=0.5, label='S/RING_Assy_DATA')
plt.hist(df_notnull['SEAL_PRESS_LOAD'], bins, alpha=0.5, label='SEAL_PRESS_LOAD')
plt.legend(loc='upper right')
plt.show()

# %%
for v in df_notnull.columns:
    plt.hist(df_notnull[v], label=v)
#plt.hist(df_notnull['SEAL_PRESS_LOAD'], label='SEAL_PRESS_LOAD')
plt.legend(loc='upper right')
plt.show()

# %%
plt.hist(df_notnull['SEAL_PRESS_LOAD'], label='SEAL_PRESS_LOAD')
plt.hist(df_notnull['SEAL_PRESS_DISTANCE'], label='SEAL_PRESS_DISTANCE')
plt.legend(loc='upper right')
plt.show()

# %%
plt.hist(df_notnull['N/R_DATA#1'], label='N/R_DATA#1')
plt.hist(df_notnull['N/R_DATA#2'], label='N/R_DATA#2')
plt.hist(df_notnull['N/R_DATA#3'], label='N/R_DATA#3')
plt.legend(loc='upper right')
plt.show()

# %%
df_notnull.plot()

# %%
df_notnull.filter(items=['EX_FRT_리크테스트값', 'Top_다윌핀_압입력_1']).plot()
