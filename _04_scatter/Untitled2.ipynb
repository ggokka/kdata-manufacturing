# %%
#!/c/Apps/Anaconda3/python
# -*- coding: utf-8 -*-
"""
[Title] Boxplot Chart
[Author] Yibeck Lee(yibec.Lee@gmail.com)
[Contents] 
 - Boxplot Chart for FDC Parameters 
"""
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


df =pd.read_csv("WIP_HISTORY.csv")
# print(df.columns)
# Index(['TARGET_VALUE', 'GOOD_BAD', 'LINE', 'EQUIPMENT', 'GAS_PRESSURE',
       # 'TEMPERATURE', 'THICKNESS', 'WAITING_TIME', 'PROCESS_TIME', 'INTENSITY',
       # 'RPM', 'TIME_GAP', 'SPEED']
df = df[['TARGET_VALUE','GAS_PRESSURE', 'TEMPERATURE', 'THICKNESS','WAITING_TIME','PROCESS_TIME','INTENSITY','RPM','TIME_GAP','SPEED']]
print(df.corr(method='pearson'))
plt.boxplot(df['PROCESS_TIME'])
plt.show()
# Out:
#               TARGET_VALUE  GAS_PRESSURE  TEMPERATURE  THICKNESS  \
# TARGET_VALUE      1.000000     -0.062426     0.048766   0.372615
# GAS_PRESSURE     -0.062426      1.000000    -0.088498  -0.066479
# TEMPERATURE       0.048766     -0.088498     1.000000   0.000777
# THICKNESS         0.372615     -0.066479     0.000777   1.000000
# WAITING_TIME      0.349891     -0.116885     0.052813   0.040017
# PROCESS_TIME      0.022198      0.018620     0.054029  -0.031659
# INTENSITY         0.309442     -0.110673     0.080717  -0.042260
# RPM               0.202264     -0.140616     0.031755  -0.002660
# TIME_GAP         -0.337871     -0.040707     0.023435   0.008198
# SPEED             0.428800      0.016965     0.041930  -0.038761
#
#               WAITING_TIME  PROCESS_TIME  INTENSITY       RPM  TIME_GAP  \
# TARGET_VALUE      0.349891      0.022198   0.309442  0.202264 -0.337871
# GAS_PRESSURE     -0.116885      0.018620  -0.110673 -0.140616 -0.040707
# TEMPERATURE       0.052813      0.054029   0.080717  0.031755  0.023435
# THICKNESS         0.040017     -0.031659  -0.042260 -0.002660  0.008198
# WAITING_TIME      1.000000     -0.098425   0.105935 -0.005850  0.111746
# PROCESS_TIME     -0.098425      1.000000   0.065897  0.043476 -0.012613
# INTENSITY         0.105935      0.065897   1.000000  0.149603  0.006070
# RPM              -0.005850      0.043476   0.149603  1.000000 -0.363079
# TIME_GAP          0.111746     -0.012613   0.006070 -0.363079  1.000000
# SPEED             0.014293      0.085077   0.138085  0.098882 -0.035095
#
#                  SPEED
# TARGET_VALUE  0.428800
# GAS_PRESSURE  0.016965
# TEMPERATURE   0.041930
# THICKNESS    -0.038761
# WAITING_TIME  0.014293
# PROCESS_TIME  0.085077
# INTENSITY     0.138085
# RPM           0.098882
# TIME_GAP     -0.035095
# SPEED         1.000000

# %%
plt.boxplot(df['SPEED'])
plt.show()

# %%
plt.boxplot(df['GAS_PRESSURE'])
plt.show()

# %%
plt.boxplot(df['RPM'])
plt.show()

# %%
df['RPM'].describe()
# Out:
# count    1.000000e+04
# mean     2.169256e+07
# std      3.110938e+07
# min      1.001700e+04
# 25%      7.926850e+04
# 50%      2.037095e+05
# 75%      4.187183e+07
# max      1.000037e+08
# Name: RPM, dtype: float64

# %%
plt.hist(df['RPM'])
plt.show()
