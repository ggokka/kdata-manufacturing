# %% [markdown]
# ```
# [Title] SPC - Xbar/R
# [Author] Yibeck Lee(yibec.Lee@gmail.com)
# [Contents]
#  - Xbar/R chart for FDC Parameters
# ```

# %%
import pandas as pd

import numpy as np
df = pd.read_csv('../data_source/WIP_HISTORY.csv')
param = 'GAS_PRESSURE'
param_values = df['GAS_PRESSURE'].as_matrix()[3000:4000]
param_values = np.reshape(param_values, (200,5)) ### *** very important
param_values[0:20]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# array([[249, 430, 318, 258, 175],
#        [142,  42,  50, 342, 273],
#        [ 36, 164,  11,  58, 328],
#        [ 71, 313, 336,  85, 408],
#        [295, 184,  18, 442, 274],
#        [ 69,  49, 253, 304, 303],
#        [ 55,  52,  49, 102,  92],
#        [ 17,  83, 102,  88, 289],
#        [  1,  76,  90,  64,  12],
#        [103,  40,  91,  55,  77],
#        [ 43, 246,  21,   9,  88],
#        [337,  86,  79,  84, 141],
#        [  8, 203,   7,  98, 246],
#        [196,  67, 102,  24, 175],
#        [  2, 250,  25, 262,  83],
#        [275,  47, 375, 320, 318],
#        [ 24, 282,  11,  66,  60],
#        [113, 142, 317,  94,  18],
#        [273, 304,  86, 174,  94],
#        [  0, 299,  30,  81, 333]], dtype=int64)

# %%
from pyspc import *
XbarR = spc(param_values) + xbar_rbar() + rbar() + rules()
print(XbarR)
# Out:
# <pyspc: (12877902)>

# %%
XbarR
# Out:
# <pyspc: (12877902)>

# %%
from pyspc import *
XbarR = spc(param_values) + xbar_rbar() + rbar() # + rules()
print(XbarR)
# Out:
# <pyspc: (12200982)>

# %%
from pyspc import *
XbarR = spc(param_values) + xbar_rbar()# + rbar() + rules()
print(XbarR)
# Out:
# <pyspc: (12438739)>

# %%
n = param_values
n.min() , n.max() , n.
# Out:
# (0, 448)
