# %%
#!/c/Apps/Anaconda3/python
# -*- coding: utf-8 -*-
"""
[Title] Histogram
[Author] Yibeck Lee(yibec.Lee@gmail.com)
[Contents] 
 - Histogram & Descriptive Statistics(기술통계)
"""
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

import pandas as pd

# font_path = 'C:/Windows/Fonts/나눔고딕코딩.ttf'
font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)


df = pd.read_csv("WIP_HISTORY.csv")

print(df.describe())
percentile = df.quantile([0.,0.001,0.002,0.1,0.25,0.5,0.75,0.999,1.0], numeric_only=False) # 0 최소값 / 0.001 0.1% / 1 MAX

print(percentile)
# Out:
#        TARGET_VALUE     GOOD_BAD          LINE     EQUIPMENT  GAS_PRESSURE  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean   78608.479900      0.27900      2.093900      2.722100    161.390900
# std     4922.822724      0.44853      0.823863      1.061218    117.888214
# min    59562.000000      0.00000      1.000000      1.000000      0.000000
# 25%    75400.000000      0.00000      1.000000      2.000000     57.000000
# 50%    78664.000000      0.00000      2.000000      3.000000    132.000000
# 75%    82013.250000      1.00000      3.000000      4.000000    272.250000
# max    93186.000000      1.00000      3.000000      4.000000    454.000000
#
#         TEMPERATURE     THICKNESS  WAITING_TIME  PROCESS_TIME     INTENSITY  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean   10969.032300   1116.047400    972.684900   6856.017000    209.133800
# std      596.853361    181.952017    109.460993   5193.419096    114.503217
# min     9747.000000    669.000000    745.000000      0.000000     36.000000
# 25%    10461.750000    989.000000    871.000000   2744.000000     95.000000
# 50%    10967.000000   1115.000000   1018.000000   5791.500000    208.000000
# 75%    11468.250000   1247.000000   1053.000000   9437.500000    322.000000
# max    12235.000000   1499.000000   1173.000000  24861.000000    378.000000
#
#                 RPM       TIME_GAP         SPEED
# count  1.000000e+04   10000.000000  10000.000000
# mean   2.169256e+07   56726.908600   9276.525900
# std    3.110938e+07   71945.939391    355.952968
# min    1.001700e+04       0.000000   8178.000000
# 25%    7.926850e+04      67.000000   9031.000000
# 50%    2.037095e+05   18872.000000   9274.000000
# 75%    4.187183e+07  100407.500000   9554.000000
# max    1.000037e+08  254234.000000   9999.000000
#        TARGET_VALUE  GOOD_BAD  LINE  EQUIPMENT  GAS_PRESSURE  TEMPERATURE  \
# 0.000     59562.000       0.0   1.0        1.0         0.000     9747.000
# 0.001     62081.761       0.0   1.0        1.0         0.000     9770.996
# 0.002     63004.524       0.0   1.0        1.0         0.000     9780.000
# 0.100     72134.600       0.0   1.0        1.0        23.000    10165.000
# 0.250     75400.000       0.0   1.0        2.0        57.000    10461.750
# 0.500     78664.000       0.0   2.0        3.0       132.000    10967.000
# 0.750     82013.250       1.0   3.0        4.0       272.250    11468.250
# 0.999     92027.097       1.0   3.0        4.0       448.001    12201.000
# 1.000     93186.000       1.0   3.0        4.0       454.000    12235.000
#
#        THICKNESS  WAITING_TIME  PROCESS_TIME  INTENSITY           RPM  \
# 0.000      669.0       745.000         0.000       36.0  1.001700e+04
# 0.001      679.0       747.000         8.999       38.0  1.029595e+04
# 0.002      683.0       747.000        16.998       40.0  1.051499e+04
# 0.100      869.0       791.000      1064.000       65.0  3.180830e+04
# 0.250      989.0       871.000      2744.000       95.0  7.926850e+04
# 0.500     1115.0      1018.000      5791.500      208.0  2.037095e+05
# 0.750     1247.0      1053.000      9437.500      322.0  4.187183e+07
# 0.999     1497.0      1164.001     23907.067      377.0  9.972701e+07
# 1.000     1499.0      1173.000     24861.000      378.0  1.000037e+08
#
#          TIME_GAP     SPEED
# 0.000       0.000  8178.000
# 0.001       0.000  8218.000
# 0.002       0.000  8261.988
# 0.100      26.000  8811.000
# 0.250      67.000  9031.000
# 0.500   18872.000  9274.000
# 0.750  100407.500  9554.000
# 0.999  251983.246  9993.001
# 1.000  254234.000  9999.000
